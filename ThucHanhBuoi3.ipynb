# %% [markdown]
# <a href="https://colab.research.google.com/github/Kandesfx/TH_DeepLearning/blob/main/ThucHanhBuoi3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BÀI TẬP MẪU
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
# Load dataset Fashion MNIST
fashion = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion.load_data()
# Reshape dữ liệu từ 28x28 -> 784
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Xây dựng ANN model
model = Sequential()
# Hidden layer
model.add(Dense(
    units=256,
    input_dim=784,
    activation='relu'
))
# Output layer
model.add(Dense(
    units=10,
    activation='softmax'
))
# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Train model
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1
)
# Đánh giá model
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy:", accuracy)
# Nhãn Fashion MNIST
labels = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}
# Dự đoán ảnh test đầu tiên
predict = model.predict(X_test)
index = 0
label = np.argmax(predict[index])
print("Predict:", labels[label])
print("True:", labels[y_test[index]])
# Hiển thị ảnh
plt.imshow(X_test[index].reshape(28,28), cmap='gray')
plt.title(labels[label])
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8254 - loss: 0.4932 - val_accuracy: 0.8428 - val_loss: 0.4248
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8642 - loss: 0.3696 - val_accuracy: 0.8600 - val_loss: 0.3759
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8791 - loss: 0.3299 - val_accuracy: 0.8748 - val_loss: 0.3456
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8866 - loss: 0.3078 - val_accuracy: 0.8807 - val_loss: 0.3262
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8940 - loss: 0.2868 - val_accuracy: 0.8808 - val_loss: 0.3192
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8979 - loss: 0.2736 - val_accuracy: 0.8872 - val_loss: 0.3255
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9031 - loss: 0.2587 - val_accuracy: 0.8823 - val_loss: 0.3252
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9072 - loss: 0.2481 - val_accuracy: 0.8853 - val_loss: 0.3275
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9119 - loss: 0.2366 - val_accuracy: 0.8917 - val_loss: 0.3178
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9139 - loss: 0.2297 - val_accuracy: 0.8867 - val_loss: 0.3224
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9181 - loss: 0.2197 - val_accuracy: 0.8827 - val_loss: 0.3389
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9202 - loss: 0.2114 - val_accuracy: 0.8842 - val_loss: 0.3521
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9227 - loss: 0.2067 - val_accuracy: 0.8893 - val_loss: 0.3333
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9251 - loss: 0.1975 - val_accuracy: 0.8863 - val_loss: 0.3464
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9281 - loss: 0.1915 - val_accuracy: 0.8850 - val_loss: 0.3615
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9293 - loss: 0.1878 - val_accuracy: 0.8855 - val_loss: 0.3475
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9332 - loss: 0.1786 - val_accuracy: 0.8898 - val_loss: 0.3588
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9342 - loss: 0.1752 - val_accuracy: 0.8888 - val_loss: 0.3358
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9366 - loss: 0.1677 - val_accuracy: 0.8908 - val_loss: 0.3508
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9391 - loss: 0.1637 - val_accuracy: 0.8915 - val_loss: 0.3709
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8864 - loss: 0.3973
# Accuracy: 0.8863999843597412
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Predict: Ankle boot
# True: Ankle boot

# %%
predict = model.predict(X_test)
labels = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}
# Hiển thị 10 ảnh đầu tiên
plt.figure(figsize=(15,5))
for i in range(10):
    predicted_label = np.argmax(predict[i])
    true_label = y_test[i]
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(
        f"P: {labels[predicted_label]}\nT: {labels[true_label]}"
    )
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# ===== Plot Accuracy =====
plt.figure(figsize=(10,5))

plt.plot(
    history.history['accuracy'],
    marker='o',
    linewidth=2,
    label='Train Accuracy'
)
plt.plot(
    history.history['val_accuracy'],
    marker='s',
    linewidth=2,
    label='Validation Accuracy'
)
plt.title('Fashion MNIST ANN Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid(True)
plt.legend(loc='lower right')
plt.savefig('fashion_mnist_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(
    history.history['loss'],
    marker='o',
    linewidth=2,
    label='Train Loss'
)
plt.plot(
    history.history['val_loss'],
    marker='s',
    linewidth=2,
    label='Validation Loss'
)
plt.title('Fashion MNIST ANN Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid(True)
plt.legend(loc='upper right')
plt.savefig('fashion_mnist_loss.png')
plt.show()

# %%
#BÀI TẬP 1
# ==========================================
# CIFAR10 IMAGE CLASSIFICATION USING ANN
# ==========================================

# ===== Import Libraries =====
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# ===== Load CIFAR10 Dataset =====
cifar10 = tf.keras.datasets.cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)

# ===== Reshape Data =====
# 32x32x3 -> 3072
X_train = X_train.reshape(50000, 3072)
X_test = X_test.reshape(10000, 3072)

# ===== Normalize Data =====
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ===== CIFAR10 Labels =====
labels = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}

# ===== Visualize Dataset =====
plt.figure(figsize=(12,6))

for i in range(10):

    plt.subplot(2,5,i+1)

    plt.imshow(X_train[i].reshape(32,32,3))

    plt.title(labels[int(y_train[i])])

    plt.axis('off')

plt.tight_layout()
plt.show()

# ===== Build ANN Model =====
model = Sequential()

# Hidden Layer 1
model.add(Dense(
    units=512,
    input_dim=3072,
    activation='relu'
))

model.add(Dropout(0.3))

# Hidden Layer 2
model.add(Dense(
    units=256,
    activation='relu'
))

model.add(Dropout(0.3))

# Hidden Layer 3
model.add(Dense(
    units=128,
    activation='relu'
))

# Output Layer
model.add(Dense(
    units=10,
    activation='softmax'
))

#Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

#Model Summary
model.summary()

#Train Model
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.1,
    verbose=1
)
#Evaluate Model
loss, accuracy = model.evaluate(X_test, y_test)
print("\nTest Accuracy:", accuracy)
#Plot Accuracy
plt.figure(figsize=(10,5))
plt.plot(
    history.history['accuracy'],
    marker='o',
    linewidth=2,
    label='Train Accuracy'
)
plt.plot(
    history.history['val_accuracy'],
    marker='s',
    linewidth=2,
    label='Validation Accuracy'
)
plt.title('CIFAR10 ANN Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig('cifar10_accuracy.png')
plt.show()
#Plot Loss
plt.figure(figsize=(10,5))
plt.plot(
    history.history['loss'],
    marker='o',
    linewidth=2,
    label='Train Loss'
)
plt.plot(
    history.history['val_loss'],
    marker='s',
    linewidth=2,
    label='Validation Loss'
)
plt.title('CIFAR10 ANN Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.savefig('cifar10_loss.png')
plt.show()
#Predict Multiple Images
predict = model.predict(X_test)

plt.figure(figsize=(15,6))

for i in range(10):

    predicted_label = np.argmax(predict[i])

    true_label = int(y_test[i])

    plt.subplot(2,5,i+1)

    plt.imshow(X_test[i].reshape(32,32,3))

    plt.title(
        f"P: {labels[predicted_label]}\nT: {labels[true_label]}"
    )

    plt.axis('off')

plt.tight_layout()

plt.savefig('cifar10_predictions.png')

plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)
# /tmp/ipykernel_901/3967036120.py:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(labels[int(y_train[i])])
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,738,890 (6.63 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.2416 - loss: 2.0429 - val_accuracy: 0.3108 - val_loss: 1.8751
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2964 - loss: 1.9087 - val_accuracy: 0.3314 - val_loss: 1.8418
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3143 - loss: 1.8628 - val_accuracy: 0.3452 - val_loss: 1.8165
# Epoch 4/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3327 - loss: 1.8321 - val_accuracy: 0.3720 - val_loss: 1.7866
# Epoch 5/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3362 - loss: 1.8159 - val_accuracy: 0.3876 - val_loss: 1.7415
# Epoch 6/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3468 - loss: 1.7909 - val_accuracy: 0.3652 - val_loss: 1.7650
# Epoch 7/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3516 - loss: 1.7805 - val_accuracy: 0.3878 - val_loss: 1.7494
# Epoch 8/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3554 - loss: 1.7664 - val_accuracy: 0.3776 - val_loss: 1.7176
# Epoch 9/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3703 - loss: 1.7429 - val_accuracy: 0.3936 - val_loss: 1.6910
# Epoch 10/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3697 - loss: 1.7417 - val_accuracy: 0.4116 - val_loss: 1.6777
# Epoch 11/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3764 - loss: 1.7242 - val_accuracy: 0.4144 - val_loss: 1.6689
# Epoch 12/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3764 - loss: 1.7199 - val_accuracy: 0.4172 - val_loss: 1.6422
# Epoch 13/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3820 - loss: 1.7025 - val_accuracy: 0.4204 - val_loss: 1.6490
# Epoch 14/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3811 - loss: 1.7096 - val_accuracy: 0.4066 - val_loss: 1.6719
# Epoch 15/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3866 - loss: 1.6981 - val_accuracy: 0.4162 - val_loss: 1.6459
# Epoch 16/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3858 - loss: 1.6956 - val_accuracy: 0.4112 - val_loss: 1.6680
# Epoch 17/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3895 - loss: 1.6884 - val_accuracy: 0.4166 - val_loss: 1.6329
# Epoch 18/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3919 - loss: 1.6845 - val_accuracy: 0.4256 - val_loss: 1.6362
# Epoch 19/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3917 - loss: 1.6820 - val_accuracy: 0.4264 - val_loss: 1.6403
# Epoch 20/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3927 - loss: 1.6740 - val_accuracy: 0.4354 - val_loss: 1.6233
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4296 - loss: 1.6144
#
# Test Accuracy: 0.4296000003814697
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /tmp/ipykernel_901/3967036120.py:169: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(y_test[i])

# %%
#BÀI TẬP @

#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

#Load MNIST Dataset
mnist = tf.keras.datasets.mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)

#Reshape Data
# 28x28 -> 784
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)

#Normalize Data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
#Labels
labels = {
    0: "Số 0",
    1: "Số 1",
    2: "Số 2",
    3: "Số 3",
    4: "Số 4",
    5: "Số 5",
    6: "Số 6",
    7: "Số 7",
    8: "Số 8",
    9: "Số 9"
}

#Visualize Dataset
plt.figure(figsize=(12,6))

for i in range(10):

    plt.subplot(2,5,i+1)

    plt.imshow(X_train[i].reshape(28,28), cmap='gray')

    plt.title(labels[y_train[i]])

    plt.axis('off')

plt.tight_layout()
plt.show()

#Build ANN Model
model = Sequential()

#Hidden Layer 1
model.add(Dense(
    units=256,
    input_dim=784,
    activation='relu'
))

model.add(Dropout(0.2))
#Hidden Layer 2
model.add(Dense(
    units=128,
    activation='relu'
))
#Output Layer
model.add(Dense(
    units=10,
    activation='softmax'
))
#Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
#Model Summary
model.summary()
#Train Model
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)

#Evaluate Model
loss, accuracy = model.evaluate(X_test, y_test)

print("\nTest Accuracy:", accuracy)

#Plot Accuracy
plt.figure(figsize=(10,5))

plt.plot(
    history.history['accuracy'],
    marker='o',
    linewidth=2,
    label='Train Accuracy'
)

plt.plot(
    history.history['val_accuracy'],
    marker='s',
    linewidth=2,
    label='Validation Accuracy'
)

plt.title('MNIST ANN Accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.grid(True)

plt.legend()

plt.savefig('mnist_accuracy.png')

plt.show()

#Plot Loss
plt.figure(figsize=(10,5))

plt.plot(
    history.history['loss'],
    marker='o',
    linewidth=2,
    label='Train Loss'
)

plt.plot(
    history.history['val_loss'],
    marker='s',
    linewidth=2,
    label='Validation Loss'
)

plt.title('MNIST ANN Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.grid(True)

plt.legend()

plt.savefig('mnist_loss.png')

plt.show()

#Predict Multiple Images
predict = model.predict(X_test)
plt.figure(figsize=(15,6))
for i in range(10):
    predicted_label = np.argmax(predict[i])
    true_label = y_test[i]
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(
        f"P: {labels[predicted_label]}\nT: {labels[true_label]}"
    )
    plt.axis('off')
plt.tight_layout()
plt.savefig('mnist_predictions.png')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/2689.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7413.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9517.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3613.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5972.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/4678.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5252.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5766.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/12391.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/12209.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9295.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8856.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9891.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9175.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10535.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3495.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/454.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5723.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/2607.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/605.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/754.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9734.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/753.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/364.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9338.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/2691.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/90.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5515.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/599.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/25.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7987.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/4490.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3267.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/11519.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8481.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/1201.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8217.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3120.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/11783.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7878.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/2867.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7370.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5272.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7156.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/1801.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3000.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8193.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/6785.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/11091.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7105.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/6710.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/4421.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/11884.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8806.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5894.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/1979.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10802.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3059.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7842.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3410.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/2085.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10371.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9843.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10129.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10226.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/4968.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7318.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10974.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5922.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/147.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9201.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5005.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8281.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7473.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5088.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5254.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/11205.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7138.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/9508.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/921.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/4463.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/7674.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3950.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8684.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/5303.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/728.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/1656.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8658.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/6119.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/8152.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/3361.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/2599.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/10035.jpg
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat/11590.jpg

# %%
import os
bhavikjikadara_dog_and_cat_classification_dataset_path = kagglehub.dataset_download('bhavikjikadara/dog-and-cat-classification-dataset')
for root, dirs, files in os.walk(bhavikjikadara_dog_and_cat_classification_dataset_path):
    print(root)

    if len(files) > 0:
        print(files[:5])  # hiện thử 5 file đầu tiên

    print("-"*50)
# Out:
# Using Colab cache for faster access to the 'dog-and-cat-classification-dataset' dataset.
# /kaggle/input/dog-and-cat-classification-dataset
# --------------------------------------------------
# /kaggle/input/dog-and-cat-classification-dataset/PetImages
# --------------------------------------------------
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Dog
# ['7981.jpg', '6234.jpg', '1269.jpg', '3863.jpg', '6241.jpg']
# --------------------------------------------------
# /kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat
# ['7981.jpg', '6234.jpg', '1269.jpg', '3863.jpg', '6241.jpg']
# --------------------------------------------------

# %%
# ============================================================
# 1. IMPORT THƯ VIỆN
# ============================================================

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES=True

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


# ============================================================
# 2. DATASET
# ============================================================

dataset_path=bhavikjikadara_dog_and_cat_classification_dataset_path

data_dir=dataset_path+"/PetImages"

print("Dataset:")
print(data_dir)


# ============================================================
# 3. DATA AUGMENTATION
# ============================================================

datagen=ImageDataGenerator(

    rescale=1./255,

    validation_split=0.2,

    rotation_range=20,

    zoom_range=0.2,

    horizontal_flip=True,

    width_shift_range=0.1,

    height_shift_range=0.1
)


train_data=datagen.flow_from_directory(

    data_dir,

    target_size=(32,32),

    batch_size=32,

    class_mode='binary',

    subset='training',

    shuffle=True
)


val_data=datagen.flow_from_directory(

    data_dir,

    target_size=(32,32),

    batch_size=32,

    class_mode='binary',

    subset='validation',

    shuffle=False
)


print("\nClass:")
print(train_data.class_indices)

print("\nTrain:",train_data.samples)

print("Validation:",val_data.samples)


# ============================================================
# 4. THỐNG KÊ DỮ LIỆU
# ============================================================

labels=train_data.classes

cat_count=np.sum(labels==0)

dog_count=np.sum(labels==1)

print("\nCat:",cat_count)

print("Dog:",dog_count)

plt.figure(figsize=(6,4))

plt.bar(
    ["Cat","Dog"],
    [cat_count,dog_count]
)

plt.title(
    "Dataset Distribution"
)

plt.show()


# ============================================================
# 5. HIỂN THỊ MẪU
# ============================================================

images,labels=next(train_data)

plt.figure(figsize=(12,8))

for i in range(9):

    plt.subplot(
        3,
        3,
        i+1
    )

    plt.imshow(
        images[i]
    )

    plt.title(
        "Dog"
        if labels[i]
        else "Cat"
    )

    plt.axis("off")

plt.show()


# ============================================================
# 6. ANN MODEL
# ============================================================

model=Sequential([

    Input(
        shape=(32,32,3)
    ),

    Flatten(),

    Dense(
        256,
        activation='relu'
    ),

    Dropout(
        0.4
    ),

    Dense(
        128,
        activation='relu'
    ),

    Dropout(
        0.3
    ),

    Dense(
        64,
        activation='relu'
    ),

    Dense(
        1,
        activation='sigmoid'
    )

])


# ============================================================
# 7. COMPILE
# ============================================================

model.compile(

    optimizer='adam',

    loss='binary_crossentropy',

    metrics=['accuracy']
)

model.summary()


# ============================================================
# 8. EARLY STOPPING
# ============================================================

early=EarlyStopping(

    monitor='val_loss',

    patience=5,

    restore_best_weights=True
)


# ============================================================
# 9. TRAIN
# ============================================================

history=model.fit(

    train_data,

    epochs=30,

    validation_data=val_data,

    callbacks=[early]
)


# ============================================================
# 10. ACCURACY
# ============================================================

plt.figure(figsize=(10,5))

plt.plot(
    history.history['accuracy']
)

plt.plot(
    history.history['val_accuracy']
)

plt.title(
    "Accuracy"
)

plt.xlabel(
    "Epoch"
)

plt.ylabel(
    "Accuracy"
)

plt.legend(
    ["Train","Validation"]
)

plt.show()


# ============================================================
# 11. LOSS
# ============================================================

plt.figure(figsize=(10,5))

plt.plot(
    history.history['loss']
)

plt.plot(
    history.history['val_loss']
)

plt.title(
    "Loss"
)

plt.xlabel(
    "Epoch"
)

plt.ylabel(
    "Loss"
)

plt.legend(
    ["Train","Validation"]
)

plt.show()


# ============================================================
# 12. ĐÁNH GIÁ
# ============================================================

loss,accuracy=model.evaluate(
    val_data
)

print("\nLoss:",loss)

print(
    "Accuracy:",
    accuracy*100,
    "%"
)


# ============================================================
# 13. CONFUSION MATRIX
# ============================================================

prediction=model.predict(
    val_data
)

prediction=(prediction>0.5)

cm=confusion_matrix(
    val_data.classes,
    prediction
)

plt.figure(figsize=(6,5))

sns.heatmap(

    cm,

    annot=True,

    fmt='d',

    xticklabels=['Cat','Dog'],

    yticklabels=['Cat','Dog']

)

plt.xlabel(
    "Predicted"
)

plt.ylabel(
    "Actual"
)

plt.show()


# ============================================================
# 14. CLASSIFICATION REPORT
# ============================================================

print(

    classification_report(

        val_data.classes,

        prediction,

        target_names=[

            "Cat",

            "Dog"

        ]

    )
)


# ============================================================
# 15. TEST 10 ẢNH
# ============================================================

images,labels=next(
    val_data
)

prediction=model.predict(
    images
)

prediction=(prediction>0.5)

plt.figure(
    figsize=(15,10)
)

for i in range(10):

    plt.subplot(
        2,
        5,
        i+1
    )

    plt.imshow(
        images[i]
    )

    predict_label=(
        "Dog"
        if prediction[i]
        else "Cat"
    )

    true_label=(
        "Dog"
        if labels[i]
        else "Cat"
    )

    plt.title(
        f"P:{predict_label}\nT:{true_label}"
    )

    plt.axis(
        "off"
    )

plt.show()
# Out:
# Dataset:
# /kaggle/input/dog-and-cat-classification-dataset/PetImages
# Found 20000 images belonging to 2 classes.
# Found 4998 images belonging to 2 classes.
#
# Class:
# {'Cat': 0, 'Dog': 1}
#
# Train: 20000
# Validation: 4998
#
# Cat: 10000
# Dog: 10000
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None,